# %% [markdown]
# # Parsing basics: JS and TS

# %%
from pathlib import Path
from tree_sitter import Language, Parser
from traverse_treesitter_tree import traverse_treesitter_tree
import json

# %%
# build treesitter parser
Language.build_library(
    'build/langs.so',
    [
        'extern/tree-sitter-javascript'
        # 'extern/tree-sitter-typescript'
    ]
)
# Out:
# False

# %%
# load TS and JS parsers
JS_LANG = Language('build/langs.so', 'javascript')
# TS_LANG = Language('build/langs.so', 'typescript')
js_parser = Parser()
js_parser.set_language(JS_LANG)
# ts_parser = Parser().set_language(TS_LANG)

# %%
# get javascript files from example/js, excluding from node_modules and hidden files (.)
js_files = []
for file in Path('example/js').glob('**/*.js'):
    if not file.name.startswith('.') and 'node_modules' not in str(file):
        js_files.append(file)

# %%
# display first 5 files newline separated
print('\n'.join(str(file) for file in js_files[:5]))
# Out:
# example/js/CodeRibbon/lib/code-ribbon-tips-view.js
# example/js/CodeRibbon/lib/cr-common.js
# example/js/CodeRibbon/lib/cr-base.js
# example/js/CodeRibbon/lib/code-ribbon-statusbar-element.js
# example/js/CodeRibbon/lib/code-ribbon-ribbon-container.js

# %%
# parse each file
parsed_js_files = []
for file in js_files:
    try:
        with open(file, 'r') as f:
            parsed_js_files.append(js_parser.parse(bytes(f.read(), 'utf-8')))
    except Exception as e:
        print(f'Error parsing {file}: {e}')

# %%
for node in traverse_treesitter_tree(parsed_js_files[-3]):
    print(node.text, node.type)
# Out:
# b"'use babel';\n\nimport CodeRibbon from '../lib/code-ribbon';\n\n// Use the command `window:run-package-specs` (cmd-alt-ctrl-p) to run specs.\n//\n// To run a specific `it` or `describe` block add an `f` to the front (e.g. `fit`\n// or `fdescribe`). Remove the `f` to unfocus the block.\n\ndescribe('CodeRibbon', () => {\n  let workspaceElement, activationPromise;\n\n  beforeEach(() => {\n    workspaceElement = atom.views.getView(atom.workspace);\n    activationPromise = atom.packages.activatePackage('code-ribbon');\n  });\n\n  describe('when the code-ribbon:toggle event is triggered', () => {\n    it('hides and shows the modal panel', () => {\n      // Before the activation event the view is not on the DOM, and no panel\n      // has been created\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it will cause the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        expect(workspaceElement.querySelector('.code-ribbon')).toExist();\n\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toExist();\n\n        let codeRibbonPanel = atom.workspace.panelForItem(codeRibbonElement);\n        expect(codeRibbonPanel.isVisible()).toBe(true);\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonPanel.isVisible()).toBe(false);\n      });\n    });\n\n    it('hides and shows the view', () => {\n      // This test shows you an integration test testing at the view level.\n\n      // Attaching the workspaceElement to the DOM is required to allow the\n      // `toBeVisible()` matchers to work. Anything testing visibility or focus\n      // requires that the workspaceElement is on the DOM. Tests that attach the\n      // workspaceElement to the DOM are generally slower than those off DOM.\n      jasmine.attachToDOM(workspaceElement);\n\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it causes the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        // Now we can test for view visibility\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toBeVisible();\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonElement).not.toBeVisible();\n      });\n    });\n  });\n});\n" program
# b"'use babel';" expression_statement
# b"'use babel'" string
# b"'" '
# b'use babel' string_fragment
# b"'" '
# b';' ;
# b"import CodeRibbon from '../lib/code-ribbon';" import_statement
# b'import' import
# b'CodeRibbon' import_clause
# b'CodeRibbon' identifier
# b'from' from
# b"'../lib/code-ribbon'" string
# b"'" '
# b'../lib/code-ribbon' string_fragment
# b"'" '
# b';' ;
# b'// Use the command `window:run-package-specs` (cmd-alt-ctrl-p) to run specs.' comment
# b'//' comment
# b'// To run a specific `it` or `describe` block add an `f` to the front (e.g. `fit`' comment
# b'// or `fdescribe`). Remove the `f` to unfocus the block.' comment
# b"describe('CodeRibbon', () => {\n  let workspaceElement, activationPromise;\n\n  beforeEach(() => {\n    workspaceElement = atom.views.getView(atom.workspace);\n    activationPromise = atom.packages.activatePackage('code-ribbon');\n  });\n\n  describe('when the code-ribbon:toggle event is triggered', () => {\n    it('hides and shows the modal panel', () => {\n      // Before the activation event the view is not on the DOM, and no panel\n      // has been created\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it will cause the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        expect(workspaceElement.querySelector('.code-ribbon')).toExist();\n\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toExist();\n\n        let codeRibbonPanel = atom.workspace.panelForItem(codeRibbonElement);\n        expect(codeRibbonPanel.isVisible()).toBe(true);\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonPanel.isVisible()).toBe(false);\n      });\n    });\n\n    it('hides and shows the view', () => {\n      // This test shows you an integration test testing at the view level.\n\n      // Attaching the workspaceElement to the DOM is required to allow the\n      // `toBeVisible()` matchers to work. Anything testing visibility or focus\n      // requires that the workspaceElement is on the DOM. Tests that attach the\n      // workspaceElement to the DOM are generally slower than those off DOM.\n      jasmine.attachToDOM(workspaceElement);\n\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it causes the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        // Now we can test for view visibility\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toBeVisible();\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonElement).not.toBeVisible();\n      });\n    });\n  });\n});" expression_statement
# b"describe('CodeRibbon', () => {\n  let workspaceElement, activationPromise;\n\n  beforeEach(() => {\n    workspaceElement = atom.views.getView(atom.workspace);\n    activationPromise = atom.packages.activatePackage('code-ribbon');\n  });\n\n  describe('when the code-ribbon:toggle event is triggered', () => {\n    it('hides and shows the modal panel', () => {\n      // Before the activation event the view is not on the DOM, and no panel\n      // has been created\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it will cause the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        expect(workspaceElement.querySelector('.code-ribbon')).toExist();\n\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toExist();\n\n        let codeRibbonPanel = atom.workspace.panelForItem(codeRibbonElement);\n        expect(codeRibbonPanel.isVisible()).toBe(true);\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonPanel.isVisible()).toBe(false);\n      });\n    });\n\n    it('hides and shows the view', () => {\n      // This test shows you an integration test testing at the view level.\n\n      // Attaching the workspaceElement to the DOM is required to allow the\n      // `toBeVisible()` matchers to work. Anything testing visibility or focus\n      // requires that the workspaceElement is on the DOM. Tests that attach the\n      // workspaceElement to the DOM are generally slower than those off DOM.\n      jasmine.attachToDOM(workspaceElement);\n\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it causes the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        // Now we can test for view visibility\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toBeVisible();\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonElement).not.toBeVisible();\n      });\n    });\n  });\n})" call_expression
# b'describe' identifier
# b"('CodeRibbon', () => {\n  let workspaceElement, activationPromise;\n\n  beforeEach(() => {\n    workspaceElement = atom.views.getView(atom.workspace);\n    activationPromise = atom.packages.activatePackage('code-ribbon');\n  });\n\n  describe('when the code-ribbon:toggle event is triggered', () => {\n    it('hides and shows the modal panel', () => {\n      // Before the activation event the view is not on the DOM, and no panel\n      // has been created\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it will cause the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        expect(workspaceElement.querySelector('.code-ribbon')).toExist();\n\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toExist();\n\n        let codeRibbonPanel = atom.workspace.panelForItem(codeRibbonElement);\n        expect(codeRibbonPanel.isVisible()).toBe(true);\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonPanel.isVisible()).toBe(false);\n      });\n    });\n\n    it('hides and shows the view', () => {\n      // This test shows you an integration test testing at the view level.\n\n      // Attaching the workspaceElement to the DOM is required to allow the\n      // `toBeVisible()` matchers to work. Anything testing visibility or focus\n      // requires that the workspaceElement is on the DOM. Tests that attach the\n      // workspaceElement to the DOM are generally slower than those off DOM.\n      jasmine.attachToDOM(workspaceElement);\n\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it causes the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        // Now we can test for view visibility\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toBeVisible();\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonElement).not.toBeVisible();\n      });\n    });\n  });\n})" arguments
# b'(' (
# b"'CodeRibbon'" string
# b"'" '
# b'CodeRibbon' string_fragment
# b"'" '
# b',' ,
# b"() => {\n  let workspaceElement, activationPromise;\n\n  beforeEach(() => {\n    workspaceElement = atom.views.getView(atom.workspace);\n    activationPromise = atom.packages.activatePackage('code-ribbon');\n  });\n\n  describe('when the code-ribbon:toggle event is triggered', () => {\n    it('hides and shows the modal panel', () => {\n      // Before the activation event the view is not on the DOM, and no panel\n      // has been created\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it will cause the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        expect(workspaceElement.querySelector('.code-ribbon')).toExist();\n\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toExist();\n\n        let codeRibbonPanel = atom.workspace.panelForItem(codeRibbonElement);\n        expect(codeRibbonPanel.isVisible()).toBe(true);\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonPanel.isVisible()).toBe(false);\n      });\n    });\n\n    it('hides and shows the view', () => {\n      // This test shows you an integration test testing at the view level.\n\n      // Attaching the workspaceElement to the DOM is required to allow the\n      // `toBeVisible()` matchers to work. Anything testing visibility or focus\n      // requires that the workspaceElement is on the DOM. Tests that attach the\n      // workspaceElement to the DOM are generally slower than those off DOM.\n      jasmine.attachToDOM(workspaceElement);\n\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it causes the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        // Now we can test for view visibility\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toBeVisible();\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonElement).not.toBeVisible();\n      });\n    });\n  });\n}" arrow_function
# b'()' formal_parameters
# b'(' (
# b')' )
# b'=>' =>
# b"{\n  let workspaceElement, activationPromise;\n\n  beforeEach(() => {\n    workspaceElement = atom.views.getView(atom.workspace);\n    activationPromise = atom.packages.activatePackage('code-ribbon');\n  });\n\n  describe('when the code-ribbon:toggle event is triggered', () => {\n    it('hides and shows the modal panel', () => {\n      // Before the activation event the view is not on the DOM, and no panel\n      // has been created\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it will cause the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        expect(workspaceElement.querySelector('.code-ribbon')).toExist();\n\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toExist();\n\n        let codeRibbonPanel = atom.workspace.panelForItem(codeRibbonElement);\n        expect(codeRibbonPanel.isVisible()).toBe(true);\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonPanel.isVisible()).toBe(false);\n      });\n    });\n\n    it('hides and shows the view', () => {\n      // This test shows you an integration test testing at the view level.\n\n      // Attaching the workspaceElement to the DOM is required to allow the\n      // `toBeVisible()` matchers to work. Anything testing visibility or focus\n      // requires that the workspaceElement is on the DOM. Tests that attach the\n      // workspaceElement to the DOM are generally slower than those off DOM.\n      jasmine.attachToDOM(workspaceElement);\n\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it causes the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        // Now we can test for view visibility\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toBeVisible();\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonElement).not.toBeVisible();\n      });\n    });\n  });\n}" statement_block
# b'{' {
# b'let workspaceElement, activationPromise;' lexical_declaration
# b'let' let
# b'workspaceElement' variable_declarator
# b'workspaceElement' identifier
# b',' ,
# b'activationPromise' variable_declarator
# b'activationPromise' identifier
# b';' ;
# b"beforeEach(() => {\n    workspaceElement = atom.views.getView(atom.workspace);\n    activationPromise = atom.packages.activatePackage('code-ribbon');\n  });" expression_statement
# b"beforeEach(() => {\n    workspaceElement = atom.views.getView(atom.workspace);\n    activationPromise = atom.packages.activatePackage('code-ribbon');\n  })" call_expression
# b'beforeEach' identifier
# b"(() => {\n    workspaceElement = atom.views.getView(atom.workspace);\n    activationPromise = atom.packages.activatePackage('code-ribbon');\n  })" arguments
# b'(' (
# b"() => {\n    workspaceElement = atom.views.getView(atom.workspace);\n    activationPromise = atom.packages.activatePackage('code-ribbon');\n  }" arrow_function
# b'()' formal_parameters
# b'(' (
# b')' )
# b'=>' =>
# b"{\n    workspaceElement = atom.views.getView(atom.workspace);\n    activationPromise = atom.packages.activatePackage('code-ribbon');\n  }" statement_block
# b'{' {
# b'workspaceElement = atom.views.getView(atom.workspace);' expression_statement
# b'workspaceElement = atom.views.getView(atom.workspace)' assignment_expression
# b'workspaceElement' identifier
# b'=' =
# b'atom.views.getView(atom.workspace)' call_expression
# b'atom.views.getView' member_expression
# b'atom.views' member_expression
# b'atom' identifier
# b'.' .
# b'views' property_identifier
# b'.' .
# b'getView' property_identifier
# b'(atom.workspace)' arguments
# b'(' (
# b'atom.workspace' member_expression
# b'atom' identifier
# b'.' .
# b'workspace' property_identifier
# b')' )
# b';' ;
# b"activationPromise = atom.packages.activatePackage('code-ribbon');" expression_statement
# b"activationPromise = atom.packages.activatePackage('code-ribbon')" assignment_expression
# b'activationPromise' identifier
# b'=' =
# b"atom.packages.activatePackage('code-ribbon')" call_expression
# b'atom.packages.activatePackage' member_expression
# b'atom.packages' member_expression
# b'atom' identifier
# b'.' .
# b'packages' property_identifier
# b'.' .
# b'activatePackage' property_identifier
# b"('code-ribbon')" arguments
# b'(' (
# b"'code-ribbon'" string
# b"'" '
# b'code-ribbon' string_fragment
# b"'" '
# b')' )
# b';' ;
# b'}' }
# b')' )
# b';' ;
# b"describe('when the code-ribbon:toggle event is triggered', () => {\n    it('hides and shows the modal panel', () => {\n      // Before the activation event the view is not on the DOM, and no panel\n      // has been created\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it will cause the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        expect(workspaceElement.querySelector('.code-ribbon')).toExist();\n\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toExist();\n\n        let codeRibbonPanel = atom.workspace.panelForItem(codeRibbonElement);\n        expect(codeRibbonPanel.isVisible()).toBe(true);\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonPanel.isVisible()).toBe(false);\n      });\n    });\n\n    it('hides and shows the view', () => {\n      // This test shows you an integration test testing at the view level.\n\n      // Attaching the workspaceElement to the DOM is required to allow the\n      // `toBeVisible()` matchers to work. Anything testing visibility or focus\n      // requires that the workspaceElement is on the DOM. Tests that attach the\n      // workspaceElement to the DOM are generally slower than those off DOM.\n      jasmine.attachToDOM(workspaceElement);\n\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it causes the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        // Now we can test for view visibility\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toBeVisible();\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonElement).not.toBeVisible();\n      });\n    });\n  });" expression_statement
# b"describe('when the code-ribbon:toggle event is triggered', () => {\n    it('hides and shows the modal panel', () => {\n      // Before the activation event the view is not on the DOM, and no panel\n      // has been created\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it will cause the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        expect(workspaceElement.querySelector('.code-ribbon')).toExist();\n\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toExist();\n\n        let codeRibbonPanel = atom.workspace.panelForItem(codeRibbonElement);\n        expect(codeRibbonPanel.isVisible()).toBe(true);\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonPanel.isVisible()).toBe(false);\n      });\n    });\n\n    it('hides and shows the view', () => {\n      // This test shows you an integration test testing at the view level.\n\n      // Attaching the workspaceElement to the DOM is required to allow the\n      // `toBeVisible()` matchers to work. Anything testing visibility or focus\n      // requires that the workspaceElement is on the DOM. Tests that attach the\n      // workspaceElement to the DOM are generally slower than those off DOM.\n      jasmine.attachToDOM(workspaceElement);\n\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it causes the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        // Now we can test for view visibility\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toBeVisible();\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonElement).not.toBeVisible();\n      });\n    });\n  })" call_expression
# b'describe' identifier
# b"('when the code-ribbon:toggle event is triggered', () => {\n    it('hides and shows the modal panel', () => {\n      // Before the activation event the view is not on the DOM, and no panel\n      // has been created\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it will cause the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        expect(workspaceElement.querySelector('.code-ribbon')).toExist();\n\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toExist();\n\n        let codeRibbonPanel = atom.workspace.panelForItem(codeRibbonElement);\n        expect(codeRibbonPanel.isVisible()).toBe(true);\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonPanel.isVisible()).toBe(false);\n      });\n    });\n\n    it('hides and shows the view', () => {\n      // This test shows you an integration test testing at the view level.\n\n      // Attaching the workspaceElement to the DOM is required to allow the\n      // `toBeVisible()` matchers to work. Anything testing visibility or focus\n      // requires that the workspaceElement is on the DOM. Tests that attach the\n      // workspaceElement to the DOM are generally slower than those off DOM.\n      jasmine.attachToDOM(workspaceElement);\n\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it causes the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        // Now we can test for view visibility\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toBeVisible();\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonElement).not.toBeVisible();\n      });\n    });\n  })" arguments
# b'(' (
# b"'when the code-ribbon:toggle event is triggered'" string
# b"'" '
# b'when the code-ribbon:toggle event is triggered' string_fragment
# b"'" '
# b',' ,
# b"() => {\n    it('hides and shows the modal panel', () => {\n      // Before the activation event the view is not on the DOM, and no panel\n      // has been created\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it will cause the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        expect(workspaceElement.querySelector('.code-ribbon')).toExist();\n\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toExist();\n\n        let codeRibbonPanel = atom.workspace.panelForItem(codeRibbonElement);\n        expect(codeRibbonPanel.isVisible()).toBe(true);\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonPanel.isVisible()).toBe(false);\n      });\n    });\n\n    it('hides and shows the view', () => {\n      // This test shows you an integration test testing at the view level.\n\n      // Attaching the workspaceElement to the DOM is required to allow the\n      // `toBeVisible()` matchers to work. Anything testing visibility or focus\n      // requires that the workspaceElement is on the DOM. Tests that attach the\n      // workspaceElement to the DOM are generally slower than those off DOM.\n      jasmine.attachToDOM(workspaceElement);\n\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it causes the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        // Now we can test for view visibility\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toBeVisible();\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonElement).not.toBeVisible();\n      });\n    });\n  }" arrow_function
# b'()' formal_parameters
# b'(' (
# b')' )
# b'=>' =>
# b"{\n    it('hides and shows the modal panel', () => {\n      // Before the activation event the view is not on the DOM, and no panel\n      // has been created\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it will cause the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        expect(workspaceElement.querySelector('.code-ribbon')).toExist();\n\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toExist();\n\n        let codeRibbonPanel = atom.workspace.panelForItem(codeRibbonElement);\n        expect(codeRibbonPanel.isVisible()).toBe(true);\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonPanel.isVisible()).toBe(false);\n      });\n    });\n\n    it('hides and shows the view', () => {\n      // This test shows you an integration test testing at the view level.\n\n      // Attaching the workspaceElement to the DOM is required to allow the\n      // `toBeVisible()` matchers to work. Anything testing visibility or focus\n      // requires that the workspaceElement is on the DOM. Tests that attach the\n      // workspaceElement to the DOM are generally slower than those off DOM.\n      jasmine.attachToDOM(workspaceElement);\n\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it causes the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        // Now we can test for view visibility\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toBeVisible();\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonElement).not.toBeVisible();\n      });\n    });\n  }" statement_block
# b'{' {
# b"it('hides and shows the modal panel', () => {\n      // Before the activation event the view is not on the DOM, and no panel\n      // has been created\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it will cause the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        expect(workspaceElement.querySelector('.code-ribbon')).toExist();\n\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toExist();\n\n        let codeRibbonPanel = atom.workspace.panelForItem(codeRibbonElement);\n        expect(codeRibbonPanel.isVisible()).toBe(true);\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonPanel.isVisible()).toBe(false);\n      });\n    });" expression_statement
# b"it('hides and shows the modal panel', () => {\n      // Before the activation event the view is not on the DOM, and no panel\n      // has been created\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it will cause the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        expect(workspaceElement.querySelector('.code-ribbon')).toExist();\n\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toExist();\n\n        let codeRibbonPanel = atom.workspace.panelForItem(codeRibbonElement);\n        expect(codeRibbonPanel.isVisible()).toBe(true);\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonPanel.isVisible()).toBe(false);\n      });\n    })" call_expression
# b'it' identifier
# b"('hides and shows the modal panel', () => {\n      // Before the activation event the view is not on the DOM, and no panel\n      // has been created\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it will cause the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        expect(workspaceElement.querySelector('.code-ribbon')).toExist();\n\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toExist();\n\n        let codeRibbonPanel = atom.workspace.panelForItem(codeRibbonElement);\n        expect(codeRibbonPanel.isVisible()).toBe(true);\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonPanel.isVisible()).toBe(false);\n      });\n    })" arguments
# b'(' (
# b"'hides and shows the modal panel'" string
# b"'" '
# b'hides and shows the modal panel' string_fragment
# b"'" '
# b',' ,
# b"() => {\n      // Before the activation event the view is not on the DOM, and no panel\n      // has been created\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it will cause the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        expect(workspaceElement.querySelector('.code-ribbon')).toExist();\n\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toExist();\n\n        let codeRibbonPanel = atom.workspace.panelForItem(codeRibbonElement);\n        expect(codeRibbonPanel.isVisible()).toBe(true);\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonPanel.isVisible()).toBe(false);\n      });\n    }" arrow_function
# b'()' formal_parameters
# b'(' (
# b')' )
# b'=>' =>
# b"{\n      // Before the activation event the view is not on the DOM, and no panel\n      // has been created\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it will cause the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        expect(workspaceElement.querySelector('.code-ribbon')).toExist();\n\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toExist();\n\n        let codeRibbonPanel = atom.workspace.panelForItem(codeRibbonElement);\n        expect(codeRibbonPanel.isVisible()).toBe(true);\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonPanel.isVisible()).toBe(false);\n      });\n    }" statement_block
# b'{' {
# b'// Before the activation event the view is not on the DOM, and no panel' comment
# b'// has been created' comment
# b"expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();" expression_statement
# b"expect(workspaceElement.querySelector('.code-ribbon')).not.toExist()" call_expression
# b"expect(workspaceElement.querySelector('.code-ribbon')).not.toExist" member_expression
# b"expect(workspaceElement.querySelector('.code-ribbon')).not" member_expression
# b"expect(workspaceElement.querySelector('.code-ribbon'))" call_expression
# b'expect' identifier
# b"(workspaceElement.querySelector('.code-ribbon'))" arguments
# b'(' (
# b"workspaceElement.querySelector('.code-ribbon')" call_expression
# b'workspaceElement.querySelector' member_expression
# b'workspaceElement' identifier
# b'.' .
# b'querySelector' property_identifier
# b"('.code-ribbon')" arguments
# b'(' (
# b"'.code-ribbon'" string
# b"'" '
# b'.code-ribbon' string_fragment
# b"'" '
# b')' )
# b')' )
# b'.' .
# b'not' property_identifier
# b'.' .
# b'toExist' property_identifier
# b'()' arguments
# b'(' (
# b')' )
# b';' ;
# b'// This is an activation event, triggering it will cause the package to be' comment
# b'// activated.' comment
# b"atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');" expression_statement
# b"atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle')" call_expression
# b'atom.commands.dispatch' member_expression
# b'atom.commands' member_expression
# b'atom' identifier
# b'.' .
# b'commands' property_identifier
# b'.' .
# b'dispatch' property_identifier
# b"(workspaceElement, 'code-ribbon:toggle')" arguments
# b'(' (
# b'workspaceElement' identifier
# b',' ,
# b"'code-ribbon:toggle'" string
# b"'" '
# b'code-ribbon:toggle' string_fragment
# b"'" '
# b')' )
# b';' ;
# b'waitsForPromise(() => {\n        return activationPromise;\n      });' expression_statement
# b'waitsForPromise(() => {\n        return activationPromise;\n      })' call_expression
# b'waitsForPromise' identifier
# b'(() => {\n        return activationPromise;\n      })' arguments
# b'(' (
# b'() => {\n        return activationPromise;\n      }' arrow_function
# b'()' formal_parameters
# b'(' (
# b')' )
# b'=>' =>
# b'{\n        return activationPromise;\n      }' statement_block
# b'{' {
# b'return activationPromise;' return_statement
# b'return' return
# b'activationPromise' identifier
# b';' ;
# b'}' }
# b')' )
# b';' ;
# b"runs(() => {\n        expect(workspaceElement.querySelector('.code-ribbon')).toExist();\n\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toExist();\n\n        let codeRibbonPanel = atom.workspace.panelForItem(codeRibbonElement);\n        expect(codeRibbonPanel.isVisible()).toBe(true);\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonPanel.isVisible()).toBe(false);\n      });" expression_statement
# b"runs(() => {\n        expect(workspaceElement.querySelector('.code-ribbon')).toExist();\n\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toExist();\n\n        let codeRibbonPanel = atom.workspace.panelForItem(codeRibbonElement);\n        expect(codeRibbonPanel.isVisible()).toBe(true);\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonPanel.isVisible()).toBe(false);\n      })" call_expression
# b'runs' identifier
# b"(() => {\n        expect(workspaceElement.querySelector('.code-ribbon')).toExist();\n\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toExist();\n\n        let codeRibbonPanel = atom.workspace.panelForItem(codeRibbonElement);\n        expect(codeRibbonPanel.isVisible()).toBe(true);\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonPanel.isVisible()).toBe(false);\n      })" arguments
# b'(' (
# b"() => {\n        expect(workspaceElement.querySelector('.code-ribbon')).toExist();\n\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toExist();\n\n        let codeRibbonPanel = atom.workspace.panelForItem(codeRibbonElement);\n        expect(codeRibbonPanel.isVisible()).toBe(true);\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonPanel.isVisible()).toBe(false);\n      }" arrow_function
# b'()' formal_parameters
# b'(' (
# b')' )
# b'=>' =>
# b"{\n        expect(workspaceElement.querySelector('.code-ribbon')).toExist();\n\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toExist();\n\n        let codeRibbonPanel = atom.workspace.panelForItem(codeRibbonElement);\n        expect(codeRibbonPanel.isVisible()).toBe(true);\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonPanel.isVisible()).toBe(false);\n      }" statement_block
# b'{' {
# b"expect(workspaceElement.querySelector('.code-ribbon')).toExist();" expression_statement
# b"expect(workspaceElement.querySelector('.code-ribbon')).toExist()" call_expression
# b"expect(workspaceElement.querySelector('.code-ribbon')).toExist" member_expression
# b"expect(workspaceElement.querySelector('.code-ribbon'))" call_expression
# b'expect' identifier
# b"(workspaceElement.querySelector('.code-ribbon'))" arguments
# b'(' (
# b"workspaceElement.querySelector('.code-ribbon')" call_expression
# b'workspaceElement.querySelector' member_expression
# b'workspaceElement' identifier
# b'.' .
# b'querySelector' property_identifier
# b"('.code-ribbon')" arguments
# b'(' (
# b"'.code-ribbon'" string
# b"'" '
# b'.code-ribbon' string_fragment
# b"'" '
# b')' )
# b')' )
# b'.' .
# b'toExist' property_identifier
# b'()' arguments
# b'(' (
# b')' )
# b';' ;
# b"let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');" lexical_declaration
# b'let' let
# b"codeRibbonElement = workspaceElement.querySelector('.code-ribbon')" variable_declarator
# b'codeRibbonElement' identifier
# b'=' =
# b"workspaceElement.querySelector('.code-ribbon')" call_expression
# b'workspaceElement.querySelector' member_expression
# b'workspaceElement' identifier
# b'.' .
# b'querySelector' property_identifier
# b"('.code-ribbon')" arguments
# b'(' (
# b"'.code-ribbon'" string
# b"'" '
# b'.code-ribbon' string_fragment
# b"'" '
# b')' )
# b';' ;
# b'expect(codeRibbonElement).toExist();' expression_statement
# b'expect(codeRibbonElement).toExist()' call_expression
# b'expect(codeRibbonElement).toExist' member_expression
# b'expect(codeRibbonElement)' call_expression
# b'expect' identifier
# b'(codeRibbonElement)' arguments
# b'(' (
# b'codeRibbonElement' identifier
# b')' )
# b'.' .
# b'toExist' property_identifier
# b'()' arguments
# b'(' (
# b')' )
# b';' ;
# b'let codeRibbonPanel = atom.workspace.panelForItem(codeRibbonElement);' lexical_declaration
# b'let' let
# b'codeRibbonPanel = atom.workspace.panelForItem(codeRibbonElement)' variable_declarator
# b'codeRibbonPanel' identifier
# b'=' =
# b'atom.workspace.panelForItem(codeRibbonElement)' call_expression
# b'atom.workspace.panelForItem' member_expression
# b'atom.workspace' member_expression
# b'atom' identifier
# b'.' .
# b'workspace' property_identifier
# b'.' .
# b'panelForItem' property_identifier
# b'(codeRibbonElement)' arguments
# b'(' (
# b'codeRibbonElement' identifier
# b')' )
# b';' ;
# b'expect(codeRibbonPanel.isVisible()).toBe(true);' expression_statement
# b'expect(codeRibbonPanel.isVisible()).toBe(true)' call_expression
# b'expect(codeRibbonPanel.isVisible()).toBe' member_expression
# b'expect(codeRibbonPanel.isVisible())' call_expression
# b'expect' identifier
# b'(codeRibbonPanel.isVisible())' arguments
# b'(' (
# b'codeRibbonPanel.isVisible()' call_expression
# b'codeRibbonPanel.isVisible' member_expression
# b'codeRibbonPanel' identifier
# b'.' .
# b'isVisible' property_identifier
# b'()' arguments
# b'(' (
# b')' )
# b')' )
# b'.' .
# b'toBe' property_identifier
# b'(true)' arguments
# b'(' (
# b'true' true
# b')' )
# b';' ;
# b"atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');" expression_statement
# b"atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle')" call_expression
# b'atom.commands.dispatch' member_expression
# b'atom.commands' member_expression
# b'atom' identifier
# b'.' .
# b'commands' property_identifier
# b'.' .
# b'dispatch' property_identifier
# b"(workspaceElement, 'code-ribbon:toggle')" arguments
# b'(' (
# b'workspaceElement' identifier
# b',' ,
# b"'code-ribbon:toggle'" string
# b"'" '
# b'code-ribbon:toggle' string_fragment
# b"'" '
# b')' )
# b';' ;
# b'expect(codeRibbonPanel.isVisible()).toBe(false);' expression_statement
# b'expect(codeRibbonPanel.isVisible()).toBe(false)' call_expression
# b'expect(codeRibbonPanel.isVisible()).toBe' member_expression
# b'expect(codeRibbonPanel.isVisible())' call_expression
# b'expect' identifier
# b'(codeRibbonPanel.isVisible())' arguments
# b'(' (
# b'codeRibbonPanel.isVisible()' call_expression
# b'codeRibbonPanel.isVisible' member_expression
# b'codeRibbonPanel' identifier
# b'.' .
# b'isVisible' property_identifier
# b'()' arguments
# b'(' (
# b')' )
# b')' )
# b'.' .
# b'toBe' property_identifier
# b'(false)' arguments
# b'(' (
# b'false' false
# b')' )
# b';' ;
# b'}' }
# b')' )
# b';' ;
# b'}' }
# b')' )
# b';' ;
# b"it('hides and shows the view', () => {\n      // This test shows you an integration test testing at the view level.\n\n      // Attaching the workspaceElement to the DOM is required to allow the\n      // `toBeVisible()` matchers to work. Anything testing visibility or focus\n      // requires that the workspaceElement is on the DOM. Tests that attach the\n      // workspaceElement to the DOM are generally slower than those off DOM.\n      jasmine.attachToDOM(workspaceElement);\n\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it causes the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        // Now we can test for view visibility\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toBeVisible();\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonElement).not.toBeVisible();\n      });\n    });" expression_statement
# b"it('hides and shows the view', () => {\n      // This test shows you an integration test testing at the view level.\n\n      // Attaching the workspaceElement to the DOM is required to allow the\n      // `toBeVisible()` matchers to work. Anything testing visibility or focus\n      // requires that the workspaceElement is on the DOM. Tests that attach the\n      // workspaceElement to the DOM are generally slower than those off DOM.\n      jasmine.attachToDOM(workspaceElement);\n\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it causes the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        // Now we can test for view visibility\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toBeVisible();\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonElement).not.toBeVisible();\n      });\n    })" call_expression
# b'it' identifier
# b"('hides and shows the view', () => {\n      // This test shows you an integration test testing at the view level.\n\n      // Attaching the workspaceElement to the DOM is required to allow the\n      // `toBeVisible()` matchers to work. Anything testing visibility or focus\n      // requires that the workspaceElement is on the DOM. Tests that attach the\n      // workspaceElement to the DOM are generally slower than those off DOM.\n      jasmine.attachToDOM(workspaceElement);\n\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it causes the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        // Now we can test for view visibility\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toBeVisible();\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonElement).not.toBeVisible();\n      });\n    })" arguments
# b'(' (
# b"'hides and shows the view'" string
# b"'" '
# b'hides and shows the view' string_fragment
# b"'" '
# b',' ,
# b"() => {\n      // This test shows you an integration test testing at the view level.\n\n      // Attaching the workspaceElement to the DOM is required to allow the\n      // `toBeVisible()` matchers to work. Anything testing visibility or focus\n      // requires that the workspaceElement is on the DOM. Tests that attach the\n      // workspaceElement to the DOM are generally slower than those off DOM.\n      jasmine.attachToDOM(workspaceElement);\n\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it causes the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        // Now we can test for view visibility\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toBeVisible();\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonElement).not.toBeVisible();\n      });\n    }" arrow_function
# b'()' formal_parameters
# b'(' (
# b')' )
# b'=>' =>
# b"{\n      // This test shows you an integration test testing at the view level.\n\n      // Attaching the workspaceElement to the DOM is required to allow the\n      // `toBeVisible()` matchers to work. Anything testing visibility or focus\n      // requires that the workspaceElement is on the DOM. Tests that attach the\n      // workspaceElement to the DOM are generally slower than those off DOM.\n      jasmine.attachToDOM(workspaceElement);\n\n      expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();\n\n      // This is an activation event, triggering it causes the package to be\n      // activated.\n      atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n\n      waitsForPromise(() => {\n        return activationPromise;\n      });\n\n      runs(() => {\n        // Now we can test for view visibility\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toBeVisible();\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonElement).not.toBeVisible();\n      });\n    }" statement_block
# b'{' {
# b'// This test shows you an integration test testing at the view level.' comment
# b'// Attaching the workspaceElement to the DOM is required to allow the' comment
# b'// `toBeVisible()` matchers to work. Anything testing visibility or focus' comment
# b'// requires that the workspaceElement is on the DOM. Tests that attach the' comment
# b'// workspaceElement to the DOM are generally slower than those off DOM.' comment
# b'jasmine.attachToDOM(workspaceElement);' expression_statement
# b'jasmine.attachToDOM(workspaceElement)' call_expression
# b'jasmine.attachToDOM' member_expression
# b'jasmine' identifier
# b'.' .
# b'attachToDOM' property_identifier
# b'(workspaceElement)' arguments
# b'(' (
# b'workspaceElement' identifier
# b')' )
# b';' ;
# b"expect(workspaceElement.querySelector('.code-ribbon')).not.toExist();" expression_statement
# b"expect(workspaceElement.querySelector('.code-ribbon')).not.toExist()" call_expression
# b"expect(workspaceElement.querySelector('.code-ribbon')).not.toExist" member_expression
# b"expect(workspaceElement.querySelector('.code-ribbon')).not" member_expression
# b"expect(workspaceElement.querySelector('.code-ribbon'))" call_expression
# b'expect' identifier
# b"(workspaceElement.querySelector('.code-ribbon'))" arguments
# b'(' (
# b"workspaceElement.querySelector('.code-ribbon')" call_expression
# b'workspaceElement.querySelector' member_expression
# b'workspaceElement' identifier
# b'.' .
# b'querySelector' property_identifier
# b"('.code-ribbon')" arguments
# b'(' (
# b"'.code-ribbon'" string
# b"'" '
# b'.code-ribbon' string_fragment
# b"'" '
# b')' )
# b')' )
# b'.' .
# b'not' property_identifier
# b'.' .
# b'toExist' property_identifier
# b'()' arguments
# b'(' (
# b')' )
# b';' ;
# b'// This is an activation event, triggering it causes the package to be' comment
# b'// activated.' comment
# b"atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');" expression_statement
# b"atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle')" call_expression
# b'atom.commands.dispatch' member_expression
# b'atom.commands' member_expression
# b'atom' identifier
# b'.' .
# b'commands' property_identifier
# b'.' .
# b'dispatch' property_identifier
# b"(workspaceElement, 'code-ribbon:toggle')" arguments
# b'(' (
# b'workspaceElement' identifier
# b',' ,
# b"'code-ribbon:toggle'" string
# b"'" '
# b'code-ribbon:toggle' string_fragment
# b"'" '
# b')' )
# b';' ;
# b'waitsForPromise(() => {\n        return activationPromise;\n      });' expression_statement
# b'waitsForPromise(() => {\n        return activationPromise;\n      })' call_expression
# b'waitsForPromise' identifier
# b'(() => {\n        return activationPromise;\n      })' arguments
# b'(' (
# b'() => {\n        return activationPromise;\n      }' arrow_function
# b'()' formal_parameters
# b'(' (
# b')' )
# b'=>' =>
# b'{\n        return activationPromise;\n      }' statement_block
# b'{' {
# b'return activationPromise;' return_statement
# b'return' return
# b'activationPromise' identifier
# b';' ;
# b'}' }
# b')' )
# b';' ;
# b"runs(() => {\n        // Now we can test for view visibility\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toBeVisible();\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonElement).not.toBeVisible();\n      });" expression_statement
# b"runs(() => {\n        // Now we can test for view visibility\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toBeVisible();\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonElement).not.toBeVisible();\n      })" call_expression
# b'runs' identifier
# b"(() => {\n        // Now we can test for view visibility\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toBeVisible();\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonElement).not.toBeVisible();\n      })" arguments
# b'(' (
# b"() => {\n        // Now we can test for view visibility\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toBeVisible();\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonElement).not.toBeVisible();\n      }" arrow_function
# b'()' formal_parameters
# b'(' (
# b')' )
# b'=>' =>
# b"{\n        // Now we can test for view visibility\n        let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');\n        expect(codeRibbonElement).toBeVisible();\n        atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');\n        expect(codeRibbonElement).not.toBeVisible();\n      }" statement_block
# b'{' {
# b'// Now we can test for view visibility' comment
# b"let codeRibbonElement = workspaceElement.querySelector('.code-ribbon');" lexical_declaration
# b'let' let
# b"codeRibbonElement = workspaceElement.querySelector('.code-ribbon')" variable_declarator
# b'codeRibbonElement' identifier
# b'=' =
# b"workspaceElement.querySelector('.code-ribbon')" call_expression
# b'workspaceElement.querySelector' member_expression
# b'workspaceElement' identifier
# b'.' .
# b'querySelector' property_identifier
# b"('.code-ribbon')" arguments
# b'(' (
# b"'.code-ribbon'" string
# b"'" '
# b'.code-ribbon' string_fragment
# b"'" '
# b')' )
# b';' ;
# b'expect(codeRibbonElement).toBeVisible();' expression_statement
# b'expect(codeRibbonElement).toBeVisible()' call_expression
# b'expect(codeRibbonElement).toBeVisible' member_expression
# b'expect(codeRibbonElement)' call_expression
# b'expect' identifier
# b'(codeRibbonElement)' arguments
# b'(' (
# b'codeRibbonElement' identifier
# b')' )
# b'.' .
# b'toBeVisible' property_identifier
# b'()' arguments
# b'(' (
# b')' )
# b';' ;
# b"atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle');" expression_statement
# b"atom.commands.dispatch(workspaceElement, 'code-ribbon:toggle')" call_expression
# b'atom.commands.dispatch' member_expression
# b'atom.commands' member_expression
# b'atom' identifier
# b'.' .
# b'commands' property_identifier
# b'.' .
# b'dispatch' property_identifier
# b"(workspaceElement, 'code-ribbon:toggle')" arguments
# b'(' (
# b'workspaceElement' identifier
# b',' ,
# b"'code-ribbon:toggle'" string
# b"'" '
# b'code-ribbon:toggle' string_fragment
# b"'" '
# b')' )
# b';' ;
# b'expect(codeRibbonElement).not.toBeVisible();' expression_statement
# b'expect(codeRibbonElement).not.toBeVisible()' call_expression
# b'expect(codeRibbonElement).not.toBeVisible' member_expression
# b'expect(codeRibbonElement).not' member_expression
# b'expect(codeRibbonElement)' call_expression
# b'expect' identifier
# b'(codeRibbonElement)' arguments
# b'(' (
# b'codeRibbonElement' identifier
# b')' )
# b'.' .
# b'not' property_identifier
# b'.' .
# b'toBeVisible' property_identifier
# b'()' arguments
# b'(' (
# b')' )
# b';' ;
# b'}' }
# b')' )
# b';' ;
# b'}' }
# b')' )
# b';' ;
# b'}' }
# b')' )
# b';' ;
# b'}' }
# b')' )
# b';' ;

# %%
# get require statements from each file
require_statements = []
for tree in parsed_js_files:
    for node in traverse_treesitter_tree(tree):
        if node.type == 'call_expression' and 'require' in str(node.text):
            require_statements.append(node.parent)

# %%
# print first 5 require statements
print('\n'.join(str(node.text) for node in require_statements[:5]))
# Out:
# b"{\n  backgroundTipsView\n} = require('./cr-base')"
# b"{\n  crdebug,\n  crlogger,\n  fuzzyFinderProjectView,\n  get_cr_panecontainer,\n  get_cr_module\n} = require('./cr-base')"
# b"scrollIntoView = require('scroll-into-view')"
# b'backgroundTipsView = require(backgroundTipsPackage.path + "/lib/background-tips-view.js")'
# b'fuzzyFinderProjectView = require("./fuzzyfinder/cr-project-view")'

# %%
# get import statements from each file
import_statements = []
for tree in parsed_js_files:
    for node in traverse_treesitter_tree(tree):
        if node.type == 'import_statement':
            import_statements.append(node)

# %%
# print first 5 import statements
print('\n'.join(str(node.text) for node in import_statements[:5]))
# Out:
# b"import CodeRibbon from '../lib/code-ribbon';"
# b"import CodeRibbonView from '../lib/code-ribbon-view';"

# %%
# use traverse_treesitter_tree to get all nodes that call a method
calls = []
for tree in parsed_js_files:
    for node in traverse_treesitter_tree(tree):
        if node.type == 'call_expression':
            calls.append(node)

# %%
len(calls)
# Out:
# 1261

# %%
# print the first 5 calls
for call in calls[:5]:
    print(call.text)
# Out:
# b"require('./cr-base')"
# b'super()'
# b'Math.round(Math.random() * len)'
# b'Math.random()'
# b"this.message.classList.remove('fade-in')"

# %%
# get all package.json files
package_json_files = []
for file in Path('example/js').glob('**/package.json'):
    if not file.name.startswith('.') and 'node_modules' not in str(file):
        package_json_files.append(file)

# %%
# print first 5 package.json files
print('\n'.join(str(file) for file in package_json_files[:5]))
# Out:
# example/js/CodeRibbon/package.json

# %%
# read each package.json file and get dependencies
dependencies = []
for file in package_json_files:
    try:
        with open(file, 'r') as f:
            dependencies.append(json.load(f)['dependencies'])
    except Exception as e:
        print(f'Error parsing {file}: {e}')

# %%
dependencies
# Out:
# [{'async': '0.2.6',
#   'atom-select-list': '^0.7.0',
#   'etch': '^0.14.1',
#   'fs-plus': '^3.0.0',
#   'fuzzaldrin': '^2.0',
#   'fuzzaldrin-plus': '^0.6.0',
#   'humanize-plus': '~1.8.2',
#   'minimatch': '~3.0.3',
#   'object-hash': '^1.3.1',
#   'scroll-into-view': '^1.16.0',
#   'temp': '^0.8.4',
#   'underscore-plus': '^1.7.0',
#   'vscode-ripgrep': '^1.13.2',
#   'wrench': '^1.5'}]
